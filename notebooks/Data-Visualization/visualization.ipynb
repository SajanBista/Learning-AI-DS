# %% [markdown]
# # Matplotlib

# %% [markdown]
# ### Line plots

# %% [markdown]
# this is my own practice creating my own reallife dataset 😭

# %%
import matplotlib.pyplot as plt
import numpy as np

# sample data
x = np.array(['1 sem','2 sem', '3 sem', '4 sem'])
y = np.array([3.32, 3.16, 3.00, 2.96])

#create the line plot 
plt.plot(x,y)

#Add labels and title

plt.xlabel("semester")
plt.ylabel("GPA")

plt.title("The result you obtained in bachelor( this is getting shit)")

#showing result 
plt.show()

# %% [markdown]
# ### Bar plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# sample data
x = np.array(['1 sem','2 sem', '3 sem', '4 sem'])
y = np.array([3.32, 3.16, 3.00, 2.96])

#create the line plot 
plt.bar(x,y)

#Add labels and title

plt.xlabel("semester")
plt.ylabel("GPA")

plt.title("The result you obtained in bachelor( this is getting shit)")

#showing result 
plt.show()

# %% [markdown]
# ### Histogram

# %%
import matplotlib.pyplot as plt #type: ignore

marks = [3.4, 3.2, 3.4, 3.59, 3.39, 3.2, 3.1, 3.0, 2.9, 3.2, 3.3, 3.3, 3.2]

plt.hist(marks, bins = 5)

plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title(" Distribution of My marks")

plt.show()

# %% [markdown]
# ### Scatter plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# sample data
x = np.array(['1 sem','2 sem', '3 sem', '4 sem'])
y = np.array([3.32, 3.16, 3.00, 2.96])

#create the line plot 
plt.scatter(x,y)

#Add labels and title

plt.xlabel("semester")
plt.ylabel("GPA")

plt.title("The result you obtained in bachelor( this is getting shit)")

#showing result 
plt.show()

# %% [markdown]
# ### Box plots

# %%
import matplotlib.pyplot as plt #type: ignore

marks = [3.4, 3.2, 3.4, 3.59, 3.39, 3.2, 3.1, 3.0, 2.9, 3.2, 3.3, 3.3, 3.2]

plt.boxplot(marks)

plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title(" Distribution of My marks")

plt.show()

# %% [markdown]
# ### Area plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# sample data
x = np.array(['1 sem','2 sem', '3 sem', '4 sem'])
y = np.array([3.32, 3.16, 3.00, 2.96])

#create the line plot 
plt.fill_between(x,y)

#Add labels and title

plt.xlabel("semester")
plt.ylabel("GPA")

plt.title("The result you obtained in bachelor( till now)")

plt.grid(True)

#showing result 
plt.show()

# %% [markdown]
# ### Stem plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# sample data
x = np.array(['1 sem','2 sem', '3 sem', '4 sem'])
y = np.array([3.32, 3.16, 3.00, 2.96])

#create the line plot 
plt.stem(x,y)

#Add labels and title

plt.xlabel("semester")
plt.ylabel("GPA")

plt.title("The result you obtained in bachelor( till now)")

plt.grid(True)

#showing result 
plt.show()

# %% [markdown]
# ### step plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# sample data
x = np.array(['1 sem','2 sem', '3 sem', '4 sem'])
y = np.array([3.32, 3.16, 3.00, 2.96])

#create the line plot 
plt.step(x,y)

#Add labels and title

plt.xlabel("semester")
plt.ylabel("GPA")

plt.title("The result you obtained in bachelor( till now)")

#plt.grid(True)

#showing result 
plt.show()

# %% [markdown]
# ### Error Bar plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# sample data
x = np.array(['1 sem','2 sem', '3 sem', '4 sem'])
y = np.array([3.32, 3.16, 3.00,2.9])

yerr = 0
#create the line plot 
plt.errorbar(x,y, yerr=yerr)

#Add labels and title

plt.xlabel("semester")
plt.ylabel("GPA")

plt.title("The result you obtained in bachelor( till now)")

#plt.grid(True)

#showing result 
plt.show()

# %% [markdown]
# ###  Heat map

# %%
data = np.random.rand(4,4)
print(data)
plt.imshow(data)

plt.show()
# Out:
# [[0.16748258 0.10456784 0.63643025 0.70647573]
#  [0.03158614 0.93621225 0.05197128 0.54129634]
#  [0.70906052 0.87096912 0.71408693 0.80172808]
#  [0.33945019 0.81482511 0.08011485 0.89481666]]

# %% [markdown]
# ### Hexibin plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (large number of points)
x = np.random.normal(0, 1, 1000)
y = np.random.normal(0, 1, 1000)

plt.hexbin(x, y)
plt.colorbar(label='Counts in bin')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Hexbin Plot of Point Density')
plt.show()

# %% [markdown]
# ### Violin plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for multiple groups (as a list of arrays)
data = [np.random.normal(0, 1, 100),
        np.random.normal(2, 1.5, 120),
        np.random.normal(-1, 0.8, 90),
        np.random.normal(3, 2, 90)]

plt.violinplot(data)
plt.xticks(np.arange(1, len(data) + 1), ['Group 1', 'Group 2', 'Group 3', 'Group 4'])
plt.ylabel('Value')
plt.title('Violin Plot of Multiple Groups')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### Swarm plots

# %%
import seaborn as sns

import pandas as pd

data = pd.DataFrame({
    'semester' : ['1 sem','2 sem', '3 sem', '4 sem', '5 sem'],
    'gpa':  [3.32, 3.16, 3.00,2.9, 3.00]
})
data
sns.swarmplot(x ='semester', y = 'gpa', data = data)
plt.title('Using swarm plot')
plt.xlabel('semester')
plt.ylabel('gpa')

plt.show()

# %% [markdown]
# ### Pair plots

# %%
data = pd.DataFrame({
    'sem 1': [3.0, 3.3, 3.0, 3.0, 2.7],
    'sem 2': [ 3, 3, 3, 2.7, 3],
    'sem 3': [2.7, 3.0, 3.0, 3.3, 3],
    'sem 4': [ 2.7, 2.7, 2.7, 3.0, 3.0]
})

sns.pairplot(data)

plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# ### Histogram

# %% [markdown]
# The displot() function will return a histogram by default. The displot() can also create a KDE or rug plot
# which are useful ways to look at the data. Seaborn can also combine these plots so you can perform more meaningful
# analysis.

# %%
#importing  the necessary libraries
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np
import pandas as pd

# %%
# Generating some sample data(a normal distribution)
np.random.seed(42) 
data_basic = np.random.normal(loc=0, scale =1, size = 1000)

plt.figure(figsize=(8,5))
sns.histplot(data = data_basic)
plt.title('Trying histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.grid(axis ='y',  alpha = 0.75)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Scatter plots
# i.e is regplot/ lmplot
